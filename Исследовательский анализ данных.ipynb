# %% [markdown]
# #Инструкция по выполнению проекта
#
# ##Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/real_estate_data.csv. Скачать датасет
#
# ##Шаг 2. Предобработка данных
# 1. Определите и изучите пропущенные значения:
# - Для некоторых пропущенных значений можно предположить логичную замену. Например, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Для других типов данных нет подходящего значения на замену. В этом случае правильно оставить эти значения пустыми. Отсутствие значения — тоже важный сигнал, который не нужно прятать.
# - Заполните пропуски, где это уместно. Опишите, почему вы решили заполнить пропуски именно в этих столбцах и как выбрали значения.
# - Укажите причины, которые могли привести к пропускам в данных.
# 2. Приведите данные к нужным типам:
# - Поясните, в каких столбцах нужно изменить тип данных и почему.
#
# ##Шаг 3. Посчитайте и добавьте в таблицу
# - цену квадратного метра;
# - день недели, месяц и год публикации объявления;
# - этаж квартиры; варианты — первый, последний, другой;
# - соотношение жилой и общей площади, а также отношение площади кухни к общей.
#
# ##Шаг 4. Проведите исследовательский анализ данных и выполните инструкции
# - Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.
# - Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
# - Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.
# - Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.
# - Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.
# - Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.
# - Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?
#
# ##Шаг 5. Напишите общий вывод
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
# ##Описание данных
# - `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# - `balcony` — число балконов
# - `ceiling_height` — высота потолков (м)
# - `cityCenters_nearest` — расстояние до центра города (м)
# - `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# - `first_day_exposition` — дата публикации
# - `floor` — этаж
# - `floors_total` — всего этажей в доме
# - `is_apartment` — апартаменты (булев тип)
# - `kitchen_area` — площадь кухни в квадратных метрах (м²)
# - `last_price` — цена на момент снятия с публикации
# - `living_area` — жилая площадь в квадратных метрах (м²)
# - `locality_name` — название населённого пункта
# - `open_plan` — свободная планировка (булев тип)
# - `parks_around3000` — число парков в радиусе 3 км
# - `parks_nearest` — расстояние до ближайшего парка (м)
# - `ponds_around3000` — число водоёмов в радиусе 3 км
# - `ponds_nearest` — расстояние до ближайшего водоёма (м)
# - `rooms` — число комнат
# - `studio` — квартира-студия (булев тип)
# - `total_area` — площадь квартиры в квадратных метрах (м²)
# - `total_images` — число фотографий квартиры в объявлении

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##Шаг 1. Откройте файл с данными и изучите общую информация

# %%
url = 'https://drive.google.com/file/d/1NJQLsTr57hVe7I9de7bnjd2YHbxI3eMu/view?usp=drive_link'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path, sep='\t')
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %% [markdown]
# ## Шаг 2. Предобработка данных
# 1. Определите и изучите пропущенные значения:
# - Для некоторых пропущенных значений можно предположить логичную замену. Например, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Для других типов данных нет подходящего значения на замену. В этом случае правильно оставить эти значения пустыми. Отсутствие значения — тоже важный сигнал, который не нужно прятать.
# - Заполните пропуски, где это уместно. Опишите, почему вы решили заполнить пропуски именно в этих столбцах и как выбрали значения.
# - Укажите причины, которые могли привести к пропускам в данных.

# %% [markdown]
# Определим в каких столбца есть пропущенные значения. Вычислим их количество и процент от общего числа.

# %%
missed_values = df.isna().sum()
missed_values = pd.DataFrame(missed_values)
missed_values = missed_values[missed_values[0]!=0].sort_values(by=0, ascending=False)
missed_values['Доля пропущенных значений, %'] = round(missed_values[0]*100/len(df),1)
missed_values = missed_values.rename(columns={0:'Кол-во пропущенных значений'})
missed_values
# Out:
#                      Кол-во пропущенных значений  Доля пропущенных значений, %
# is_apartment                               20924                          88.3
# parks_nearest                              15620                          65.9
# ponds_nearest                              14589                          61.6
# balcony                                    11519                          48.6
# ceiling_height                              9195                          38.8
# airports_nearest                            5542                          23.4
# cityCenters_nearest                         5519                          23.3
# parks_around3000                            5518                          23.3
# ponds_around3000                            5518                          23.3
# days_exposition                             3181                          13.4
# kitchen_area                                2278                           9.6
# ...

# %% [markdown]
# Довольно много столбцов имеют большое количество пропущенных значений. Можно их разделить на три категории:
# 1. столбцы, где можно оставить пропуски, так как довольно сложно определить на что заменять пропущенные значения. Для этих столбцов не стоит задача анализа в этом проекте. Скорее всего этот признак для объекта недвижимости точно не известен и при заполнении эту графу оставили просто пустой. К ним относится:
#   - `is_apartment(апартаменты(булев тип))` 88% пропущенных значений;
#   - `parks_nearest(расстояние до ближайшего парка(м))` 66% пропущено;
#   - `ponds_nearest(расстояние до ближайшего водоема(м))` 62% пропущено;
#   - `airport_nearest(расстояние до ближайшего аэропорта в метрах(м))` 23% пропущено;
#   - `parks_around3000(число парков в радиусе 3 км)` 23% пропущено;
#   - `ponds_around3000(число водоемов в радиусе 3 км)` 23% пропущено;
# 2. столбцы, которые являются предметом исследовательского анализа данного проекта. Эти столбцы требуеют более тщательного изучения и дальнейшего приня тия решения о замене пропусков. К ним относятЖ
#   - `ceiling_hight(высота потолков в (м))` 39% пропущенных значений;
#   - `days_exposition(сколько дней было размещено объявление(от публикации до снятия))`  13% пропущено;
#   - `kitchen_area(площадь кухни в квадратных метрах)` 10% пропущено;
#   - `living_area(жилая площадь в квадратных метрах)` 8% пропущено;
#   - `cityCenters_nearest(расстояние до центра города в (м))` 23% пропущено;
# 3. столбцы, где можно легко заполнить пропуски и столбцы, где доля пропусков ничтожно мала и от строк с пропусками в этих столбцах можно безболезненно избавиться. К ним относятся:
#  - `balcony(число балконов)` 49% пропущено. Здесь скорее всего пропущенные значения означают отсутствие балкона, поэтому в дальнейшем заполним пропуски в этом столбце нулями;
#  - `floors_total(всего этажей в доме)` 0.4% пропущено. Удалим строки с пропусками в этом столбце;
#  - `locality_name(название населенного пункта)` - 0.2% пропущено. Также удалим строки с пропусками в этом столбце.

# %% [markdown]
# Заменим все пропуски в `balcony` на 0, и удалим строки где есть пропуски в `floors_total` и `locality_name`

# %%
data = df.copy()
data.loc[data['balcony'].isna(),'balcony'] = 0
data['balcony'].isna().sum()
# Out:
# 0

# %%
data = data.dropna(subset=['floors_total', 'locality_name']).reset_index(drop=True)
print(f'Доля удаленных строк : {len(df)/len(data) - 1:.1%}')
# Out:
# Доля удаленных строк : 0.6%

# %% [markdown]
# Проанализируем пропуски в `ceiling_hight(высота потолков в (м))`.

# %%
data['ceiling_height'].describe()
# Out:
# count    14481.000000
# mean         2.771283
# std          1.261983
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data.boxplot(['ceiling_height'])
plt.ylim(2,4)
plt.show()

# %%
data['ceiling_height'].hist(bins=30,range=(2.2, 3.23))
plt.xlabel('Высота потолков, м')
plt.ylabel('Количество, шт')
plt.title('Гистограмма высоты потолков')
plt.show()

# %% [markdown]
# Медиана равна 2.65 метра, среднее значение 2.77 метра. Значит есть очень много выбросов, которые гораздо больше среднего значения. Нормальные значения лежат в диапазоне 2.2 - 3.23 метра. Все что за пределелами этого диапазона - выбросы. Больше всего количество квартир с высотой потолков 2.5 метра.
# Заменим все пропуски в `ceiling_height` на медианное значение 2.65 м , так медиана не подвержена влиянию выбросов.

# %%
data.loc[data['ceiling_height'].isna(), 'ceiling_height'] = data['ceiling_height'].median()
data['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
#   Пропуски в  `days_exposition(сколько дней было размещено объявление(от публикации до снятия)) появились на тех объектах недвижимости, которые еще продавались на момент выгрузки данных этого датафрейма, то есть объявление о продаже было размещено, но покупатель не был найдет. Поэтому оставим пропуски без изменений в этой колонке.

# %% [markdown]
# Пропуски в `kitchen_area` и `living_area` предположительно стоят в объектах недвижимости, где кухня совмещенная с гостинной или в квартире-студии. В таких объектах трудно определить, где заканчиватся одна зона и начинается другая.
# Пропуск в `cityCenters_nearest` скорее всего характерны для небольших населенных пунктов, где понятие "центр города" не так важно, как для городов - мегаполисов. Пока оставим пропуски в этих столбцах без изменений.

# %% [markdown]
# 2. Приведите данные к нужным типам:
# - Поясните, в каких столбцах нужно изменить тип данных и почему.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  object
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  float64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# Столбцы `floors_total`, `floor`, `balcony`, `airports_nearest`, `cityCenters_nearest`, `parks_around3000`, `parks_nearest`, `ponds_around3000`, `ponds_nearst`, `days_exposition` нужно перевести в тип `int`.

# %%
lst = ['floors_total', 'floor', 'balcony', 'airports_nearest', 'cityCenters_nearest',
       'parks_around3000', 'parks_nearest', 'ponds_around3000',
       'ponds_nearest', 'days_exposition']
for column in lst:
  data[column]  = data[column].astype('int', errors='ignore')

# %% [markdown]
# Столбец `first_day_exposition` нужно привести к типу `datetime` для полноценной работой с датой и временем.

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           21700 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          21343 non-null  float64
#  13  balcony               23565 non-null  int64
# ...

# %% [markdown]
# ##Шаг 3. Посчитайте и добавьте в таблицу
# - цену квадратного метра;
# - день недели, месяц и год публикации объявления;

# %%
data['price_m2'] = data['last_price']/data['total_area']
data['week_day'] = data['first_day_exposition'].dt.weekday
data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23560             9   9700000.0      133.81           2017-03-21      3
# 23561            14   3100000.0       59.00           2018-01-15      3
# 23562            18   2500000.0       56.70           2018-02-11      2
# 23563            13  11475000.0       76.75           2017-03-28      2
# 23564             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# - этаж квартиры; варианты — первый, последний, другой;

# %%
def floor_cat(row):
  if row['floor']==1:
    return 'первый'
  if row['floors_total']==row['floor']:
    return 'последний'
  return 'другой'

# %%
data['floor_cat'] = data.apply(floor_cat, axis=1)
data[['floors_total', 'floor', 'floor_cat']].sample(10, random_state=43)
# Out:
#        floors_total  floor  floor_cat
# 16386             9      7     другой
# 18456             5      3     другой
# 9065              5      2     другой
# 17582             5      5  последний
# 19710             9      9  последний
# 9332             15      1     первый
# 6413              5      4     другой
# 23088             9      3     другой
# 3002             18     17     другой
# 1169             24      2     другой

# %% [markdown]
# - соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %%
data['liv/total'] = data['living_area']/data['total_area']
data['kit/total'] = data['kitchen_area']/data['total_area']
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16         51.0      8          NaN  ...
# 1            2.65            11         18.6      1          NaN  ...
# 2            2.65             5         34.3      4          NaN  ...
# 3            2.65            14          NaN      9          NaN  ...
# 4            3.03            14         32.0     13          NaN  ...
#
#    ponds_around3000  ponds_nearest  days_exposition       price_m2 week_day  \
# ...

# %% [markdown]
# ##Шаг 4. Проведите исследовательский анализ данных и выполните инструкции
# - Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.

# %%
data['total_area'].hist(bins=50, range=(0,400))
plt.xlabel('Общая площадь, м2')
plt.ylabel('Количесво объектов недвижимости, шт')
plt.title('Гистограмма общей площади')
plt.show()

# %%
data['total_area'].describe()
# Out:
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %%
data.boxplot('total_area')
plt.ylim(0,115)
plt.show()

# %% [markdown]
# Общая площадь квартир в базе данных лежит в диапазоне от 12 до 900 м2. Нормальные значения лежат в пределах от 12 до 115м2 - все что не укладывается в данный диапазон является выбросами. На гистограмме видно, что объекты больше 150 м2 крайне редки и большинство объектов имеют площадь около 50 м2. Медианное значение 52м2, среднее значение 60м2.

# %%
data['last_price'].describe()
# Out:
# count    2.356500e+04
# mean     6.540058e+06
# std      1.091093e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.646000e+06
# 75%      6.790000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Для удобства будем оперировать миллионами в цене.

# %%
data['last_price'] = data['last_price']/10**6

# %%
data['last_price'].hist(bins=50,range=(0,40))
plt.xlabel('Цена объекта в млн, руб')
plt.ylabel('Количество объектов, шт')
plt.title('Гистограмма цены ')
plt.show()

# %%
data.boxplot('last_price')
plt.ylim(0,12)
plt.show()

# %% [markdown]
# Цена в датасете варьируется в пределах от 12190 руб до 763 млн. рублей. Нормальными значениями являются значения в диапазоне от 0.12 до 11.875 млн. рублей. Медиана равна 4.64 млн. руб, среднее значение 6.54 млн. руб. На гистограмме видно, что большинство объектов имеют цену около 5 млн, и предложения по цене больше 15 млн. крайне редки.

# %%
data['rooms'].hist(bins=20, range=(0,10))
plt.xlabel('Количество комнат, шт')
plt.ylabel('Количество объектов недвижимости, шт')
plt.title('Гистограмма количетва комнат')
plt.show()

# %%
data['rooms'].describe()
# Out:
# count    23565.000000
# mean         2.070656
# std          1.078591
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
data.boxplot('rooms')
plt.ylim(0,8)
plt.show()

# %% [markdown]
# Диапазон всех возможных значений количества комнат в наборе данных лежит в пределах от 0 до 19 комнат. Нормальными значениями ялвяются, те что попадают в диапазон от 0 - 6 комнат, все что за пределами этого диапазона - выбросы. Медианное и среднее значение - 2. На гистограмме видно, что львиная доля все квартир это 1-, 2- и 3-х комнатные квартиры. Количество комнат 4 и более встречаются уже гораздо реже.

# %%
data.boxplot('ceiling_height')
plt.ylim(2.4,2.9)
plt.show()

# %%
data['ceiling_height'].describe()
# Out:
# count    23565.000000
# mean         2.724530
# std          0.991026
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].hist(bins=40, range=(2, 5))
plt.xlabel('Высота потолков, м')
plt.ylabel('Количество объектов, шт')
plt.title('Гистограмма высоты потолков')
plt.show()

# %% [markdown]
# Нормальная высота потолков лежит в пределах от 2,45 - 2,85 метра. Медианное значение 2.65 метра.

# %% [markdown]
# - Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
data['days_exposition'].describe()
# Out:
# count    20394.000000
# mean       180.741395
# std        219.732782
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data.boxplot('days_exposition')
plt.ylim(0,550)
plt.show()

# %%
data['days_exposition'].hist(bins=100)
plt.xlabel('Количество дней, которое продавался объект')
plt.ylabel('Количетсво объектов недвижимости, шт')
plt.title('Гистограмма количества дней продажи')
plt.show()

# %%
data['days_exposition'].mean()
# Out:
# 180.7413945278023

# %%
data['days_exposition'].median()
# Out:
# 95.0

# %% [markdown]
# Основная доля объектов продается от 45 дней до 231 дня. Все что меньше 45 дней можно считать быстрой продажей. Все что больше 231 и меньше 510 дней можно считать долгой продажей.

# %% [markdown]
# - Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %%
data[data['days_exposition']<=510]['days_exposition'].hist(bins=500)
plt.xlim(0,150)
plt.xlabel('Количество дней продажи')
plt.ylabel('Количество объектов недвижимости')
plt.title('Гистрограмма кол-ва дней продажи без выбросов')
plt.xticks(range(0,150,15))
plt.show()

# %% [markdown]
#  На гистограмме выше видны явные всплески на 45, 60 и 90 дней продажи. Возможно это связано с тем, что если объявление о продаже не было активно, то оно снималось с публикации в эти дни.

# %% [markdown]
# - Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# Изучим зависимость цены от площади для этого создадим столбец `last_price_cat` по принципу если цена попадает в диапазон 0-1 млн, тогда присваиваем этой категории значение 0, от 1-2 млн- 1 , 2-3 - 2 и так далее. Далее сделаем группировку по этой категории и посчитаем среднее значение общей площади квартир.

# %%
data['last_price'].describe()
# Out:
# count    23565.000000
# mean         6.540058
# std         10.910935
# min          0.012190
# 25%          3.400000
# 50%          4.646000
# 75%          6.790000
# max        763.000000
# Name: last_price, dtype: float64

# %%
data['last_price_cat'] = data['last_price'].astype('int')
data[['last_price', 'last_price_cat']].sample(5)
# Out:
#        last_price  last_price_cat
# 12804        6.30               6
# 8402         3.75               3
# 8601         8.50               8
# 8044         3.57               3
# 16579       14.75              14

# %%
data.groupby('last_price_cat')['total_area'].mean().plot(style='o-', figsize=(15,5), grid=True)
plt.xlabel('Цена продажи объекта недвижимости, млн')
plt.ylabel('Общая площадь объекта недвижимости, м2')
plt.title('Зависимость цены от площади объекта недвижимости')
plt.show()

# %%
data.groupby('last_price_cat')['total_area'].mean().plot(style='o-', figsize=(10,5), grid=True)
plt.xlabel('Цена продажи объекта недвижимости, млн')
plt.ylabel('Общая площадь объекта недвижимости, м2')
plt.title('Зависимость цены от площади объекта недвижимости')
plt.ylim(0,250)
plt.xlim(0,35)
plt.xticks(range(35))
plt.show()

# %%
data.groupby('last_price_cat')['total_area'].mean().plot(style='o-', figsize=(10,5), grid=True)
plt.xlabel('Цена продажи объекта недвижимости, млн')
plt.ylabel('Общая площадь объекта недвижимости, м2')
plt.title('Зависимость цены от площади объекта недвижимости')
plt.ylim(0,60)
plt.xlim(0,5)
plt.show()

# %% [markdown]
# Можно выделить три участка на вышеуказанных графиках:
# - 0-4 млн. здесь зависимости от цены нет и можно найти предложения с средней площадью 42м2;
# - 4 - 18 млн. здесь наблюдается положительная линейная зависимость и с ростом цены можно найти предложения со средней площадью от 42 до 125м2;
# - более 18 млн. здесь уже линейной зависимости от площади не наблюдается.

# %%
data.groupby('rooms')['last_price'].mean().plot(kind='bar', grid=True)
plt.xlabel('Количество комнат в объекте недвижимости')
plt.ylabel('Средняя цена продажи, млн. руб')
plt.title('Зависимость средней площади квартир от числа комнат')
plt.show()

# %%
data.groupby('rooms')['last_price'].mean().plot(kind='bar', grid=True)
plt.xlabel('Количество комнат в объекте недвижимости')
plt.ylabel('Средняя цена продажи, млн. руб')
plt.xlim(0,8)
plt.ylim(0,60)
plt.title('Зависимость средней площади квартир от числа комнат')
plt.yticks(range(0,60,5))
plt.show()

# %% [markdown]
# Можно выделить два участка:
#  - от 0 до 7 комнат здесь есть положиетльная нелинейная(похоже на квадратичную) зависимость между количеством комнат и средней ценой;
#  - для объектов обладающих более 8 комнатами явного тренда не наблюдается. Можно найти объекты с 10-ю комнатами, которые будут по цене примерно 6-ти комнатных объектов.

# %% [markdown]
# В столбце `cityCenters_nearest` содержатся пропущенные значения. Максимальное значение в этом столбце 65968 метров. Для того, чтобы провести анализ зависимости от стоимости заменим все пропущенные значения на 100000м, но отметим для себя, что это будет касаться пропущенных значений. Проведем категоризацию данного столбца следующим образом: значения от 0 до 1000 метров будут соответсвовать 0му километру, от 1000 до 2000м  - 2 км и т.д. Далее группируем по этому параметру и рассчитаем среднюю цену.

# %%
data['cityCenters_nearest'] = data['cityCenters_nearest'].fillna(100000)
data['cityCenters_nearest'].isna().sum()
# Out:
# 0

# %%
data['distance'] = (data['cityCenters_nearest']/1000).astype('int')

# %%
data[['cityCenters_nearest', 'distance']].sample(10)
# Out:
#        cityCenters_nearest  distance
# 1487                4586.0         4
# 15692              11870.0        11
# 79                100000.0       100
# 18465             100000.0       100
# 13749             100000.0       100
# 384               100000.0       100
# 10807                318.0         0
# 3172               11677.0        11
# 141                 5448.0         5
# 4750               15859.0        15

# %%
data.groupby('distance')['last_price'].mean().plot(kind='bar', figsize=(15,5), grid=True)
plt.xlabel('Расстояние до центра города, км')
plt.ylabel('Средняя стоимость объекта недвижимости, млн. руб')
plt.title('Зависимость стоимости от расстояния до центра города')

plt.show()

# %% [markdown]
# Можно выделить два участка:
#  - зона с радиусом 8 км до центра города, здесь квартиры стоят значительно дороже,
#  - зона, которая удалено от центра города более чем на 8 км, здесь средняя стоимость объектов находится около 5 млн. руб.
#  Также выделяются 42км и 54км здесь стоимость сопоставима с объектами расположенными в центре города.

# %%
data.groupby('floor_cat')['last_price'].mean().sort_values().plot(kind='bar')
plt.xlabel('Этаж')
plt.ylabel('Средняя стоимость квартиры, млн. руб')
plt.title('Зависимость средней стоимости от этажа')
plt.show()

# %% [markdown]
# Видно, что квартиры на первом этаже являются самыми дешевыми. Самые дорогие объекты расположены на последнем этаже. Средний ценовой диапазон присущ объектам расположенным ни на первом и ни на последнем этажах.

# %%
result_week_day = data.groupby('week_day')['last_price'].mean()
result_week_day.index = ['Пн', 'Вт', 'Ср', 'Чт', 'Пт', 'Сб', 'Вс']
result_week_day.plot(kind='bar', grid=True)
plt.xlabel('День недели, в котором было размещено объявление')
plt.ylabel('Средняя стоимость, млн. руб')
plt.title('Зависимость средней стоимости от дня размещения ')
plt.ylim(6,7)
# Out:
# (6.0, 7.0)

# %% [markdown]
# Диапазон средней цены в зависимости от дня недели, в котором было  размещено объявление находится в пределах 6,24 - 6,98 млн. Самые дороги квартиры размщались в субботы, самые дешевые в воскресень, хотя изменение между максимальной и минимальной ценой почти не наблюдается.

# %%
data.groupby('month')['last_price'].mean().plot(kind='bar', grid=True)
plt.ylim(6,7.2)
plt.xlabel('месяц')
plt.ylabel('Средняя стоимость объекта, млн. руб')
plt.title('Зависимость средней стоимость от месяца размещения')
plt.show()

# %% [markdown]
# Минимальная средняя цена 6,23 млн зафиксирована в октябре, максимальная 7,00 млн. руб в декабре.

# %%
data.groupby('year')['last_price'].mean().plot(kind='bar', grid=True)
#plt.ylim(6,7.2)
plt.xlabel('месяц')
plt.ylabel('Средняя стоимость объекта, млн. руб')
plt.title('Зависимость средней стоимость от года размещения')
plt.show()

# %% [markdown]
# Виден падающий тренд средней цены с 2014 года по 2018 год. Средняя цена в 2014 года составляла около 12 млн. руб, в 2018 - 6 млн. руб.

# %% [markdown]
# - Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %%
result_locality  = (data.groupby('locality_name')['price_m2']
                        .agg(['count', 'mean'])
                        .sort_values(by='count', ascending=False)
                        .head(10)
                        .reset_index())
result_locality.index = range(1,11)
result_locality.columns = ['Населенный пункт', 'Кол-во объявлений', 'Средняя стоимость м2']
result_locality
# Out:
#      Населенный пункт  Кол-во объявлений  Средняя стоимость м2
# 1     Санкт-Петербург              15651         114868.877341
# 2      посёлок Мурино                520          85673.259928
# 3      посёлок Шушары                439          78551.344545
# 4          Всеволожск                398          68654.473986
# 5              Пушкин                369         103125.819291
# 6             Колпино                338          75424.579098
# 7   посёлок Парголово                327          90175.913458
# 8             Гатчина                307          68746.146763
# 9     деревня Кудрово                299          92473.547576
# 10             Выборг                237          58141.909153

# %%
result_locality.sort_values(by='Средняя стоимость м2', ascending=False)
# Out:
#      Населенный пункт  Кол-во объявлений  Средняя стоимость м2
# 1     Санкт-Петербург              15651         114868.877341
# 5              Пушкин                369         103125.819291
# 9     деревня Кудрово                299          92473.547576
# 7   посёлок Парголово                327          90175.913458
# 2      посёлок Мурино                520          85673.259928
# 3      посёлок Шушары                439          78551.344545
# 6             Колпино                338          75424.579098
# 8             Гатчина                307          68746.146763
# 4          Всеволожск                398          68654.473986
# 10             Выборг                237          58141.909153

# %% [markdown]
# Самой высокой средней стоимостью квадратного метра жилья обладает посёлок Санкт-Петербург. Там приобрести один квадратный метр жилья можно  почти за 115000 руб. На десятом месте населенный пункт Выборг. Стоимость одного квадратного метра в этом населенном пункте составляет 58000 рублей.

# %% [markdown]
# - Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.

# %%
(data.loc[data['locality_name']=='Санкт-Петербург']
     .groupby('distance')['last_price']
     .mean()
     .plot(kind='bar',
           figsize=(15,5),
           grid=True))
plt.xlabel('Расстояние до центра Санкт-Петербурга, км')
plt.ylabel('Средняя стоимость объекта недвижимости, млн. руб')
plt.title('Зависимость стоимости от расстояния до центра Санкт-Петербурга')

plt.show()

# %% [markdown]
# На графике видно, что цена резко меняется после 8го километра. Будем считать центральной частью область, которая удалена от центра не более чем на 8 км.

# %% [markdown]
# - Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %%
spb_center = data.loc[(data['locality_name']=='Санкт-Петербург') & (data['cityCenters_nearest']<8000)]
spb = data.loc[(data['locality_name']=='Санкт-Петербург')]

# %%
ax = spb_center['total_area'].plot(kind='hist',
                                   range=(0,200),
                                   bins=50,
                                   color='b',
                                   label='Центр',
                                   legend=True,
                                   grid=True,
                                   figsize=(10,5))
spb['total_area'].plot(kind='hist',
                       range=(0,200),
                       bins=50,
                       color='g',
                       ax=ax,
                       alpha=0.4,
                       label='Санкт-Петербург',
                       grid=True,
                       legend=True)
plt.xlabel('Площадь, м2')
plt.ylabel('Количество объектов, шт')
plt.title('Гистограмма общей площади объектов в центре и по всему городу')
plt.show()

# %% [markdown]
# В центре Санкт-Петербурга основная масса объектов имеют большую площадь по сравнению со всем городом. Для центра очень большой выбор объектов недвижимости в диапазоне от 50 до 75 м2, тогда как большая часть объектов для всего города имеют площадь менее 50 м2.

# %%
ax = spb_center['last_price'].plot(kind='hist',
                                   range=(0,30),
                                   bins=100,
                                   color='b',
                                   label='Центр',
                                   legend=True,
                                   grid=True,
                                   figsize=(10,5))
spb['last_price'].plot(kind='hist',
                       range=(0,30),
                       bins=100,
                       color='g',
                       ax=ax,
                       alpha=0.4,
                       label='Санкт-Петербург',
                       grid=True,
                       legend=True)
plt.xlabel('Цена объекта недвижимости, млн. руб')
plt.ylabel('Количество объектов, шт')
plt.title('Гистограмма стоимости объектов в центре и по всему городу')
plt.show()

# %% [markdown]
# В центре Санкт-Петербурга продаются более дорогие квартиры по сравнению со всем городом. В центре большинство объектов продаются по цене от 5 до 10 млн руб, тогда как для всего города большинство объектов продаются по цене от 3 до 7 млн.

# %%
ax = spb_center['rooms'].plot(kind='hist',
                              range=(0,10),
                              bins=30,
                              color='b',
                              label='Центр',
                              legend=True,
                              grid=True,
                              figsize=(10,5))
spb['rooms'].plot(kind='hist',
                  range=(0,10),
                  bins=30,
                  color='g',
                  ax=ax,
                  alpha=0.4,
                  label='Санкт-Петербург',
                  grid=True,
                  legend=True)
plt.xlabel('Число комнат, шт')
plt.ylabel('Количество объектов, шт')
plt.title('Количество комнат у объектов в центре и по всему городу')
plt.show()

# %% [markdown]
# Выбор однокомнатных квартир в центре в два раза меньше по сравнению с 2-х и 3-х комнатными вариантами, тогда как для всего города количество однокомнатных квартир почти одинаково по сравнению с двухкомнатными.

# %%
ax = spb_center['ceiling_height'].plot(kind='hist',
                                       range=(2,5),
                                       bins=30,
                                       color='b',
                                       label='Центр',
                                       legend=True,
                                       grid=True,
                                       figsize=(10,5))
spb['ceiling_height'].plot(kind='hist',
                           range=(2,5),
                           bins=30,
                           color='g',
                           ax=ax,
                           alpha=0.4,
                           label='Санкт-Петербург',
                           grid=True,
                           legend=True)
plt.xlabel('Высота потолков, м')
plt.ylabel('Количество объектов, шт')
plt.title('Высота потолков объектов в центре и по всему городу')
plt.show()

# %% [markdown]
# Распределение по высоте потолков в центре и по всему городу приблизительн одинаково.

# %%
ax = spb_center.groupby('rooms')['last_price'].mean().plot(kind='bar',
                                                           color='g',
                                                           alpha=0.6,
                                                           label='Центр',
                                                           legend=True)
data.groupby('rooms')['last_price'].mean().plot(kind='bar',
                                                ax=ax,
                                                alpha=0.2,
                                                color='r',
                                                label='Вся база данных',
                                                legend=True)
plt.xlabel('Количество комнат')
plt.ylabel('Стоимость объекта недвижимости, млн. руб.')
plt.title('Зависимость стоимости от кол-ва комнат')
plt.show()

# %% [markdown]
# Зависимость средней стоимости квартир от количество комнат для центра Санкт-Петербурга и всей базы данных одинакова, за исключением того, что в центре стоимость квартир выше.

# %%
ax = (spb_center.groupby('floor_cat')['last_price']
                .mean()
                .sort_values()
                .plot(kind='bar',
                      color='g',
                      alpha=0.6,
                      label='Центр',
                      legend=True))
(data.groupby('floor_cat')['last_price']
     .mean()
     .sort_values()
     .plot(kind='bar',
           ax=ax,
           alpha=0.2,
           color='r',
           label='Вся база данных',
           legend=True))
plt.xlabel('Этаж')
plt.ylabel('Средняя стоимость, млн. руб')
plt.title('Зависимость стоимости от этажа')
plt.show()

# %% [markdown]
# Зависимость стоимости квартиры от этажа для центра Санкт-Петербурга и всей базы данных одинакова. Самые дешевые объекты продаются на первом этаже, самы дорогие - на последнем, средний ценовой диапазон принадлежит объектам межды первым и последним этажами.

# %%
ax = spb_center.groupby('distance')['last_price'].mean().plot(kind='bar',
                                                              color='g',
                                                              alpha=0.2)
(data.loc[data['distance']<8]
     .groupby('distance')['last_price'].mean()
     .plot(kind='bar',
           ax=ax,
           alpha=0.2,
           color='r'))
plt.xlabel('Расстояние до центра, км')
plt.ylabel('Средняя стоимость объектов, млн. руб')
plt.title('Зависимость стоимотсти от расстояния до центра')
plt.show()

# %% [markdown]
# Зависимость стоимости от расстояния до центра города для центра Санкт-Петербурга и всей базы данных одинакова.

# %%
ax = (spb_center.groupby('first_day_exposition')['last_price'].mean()
                .plot(figsize=(15,5),
                 color='g'))
data.groupby('first_day_exposition')['last_price'].mean().plot(figsize=(15,5),
                                                               color='r')
plt.xlabel('Дата размещения объявления')
plt.ylabel('Средняя стоимость, млн. руб')
plt.title('Зависимость средней стоимости объекта недвижимости от даты размещения')
plt.show()

# %% [markdown]
# Явной зависимости средней стоимости объекта недвижимости от даты размещения не наблюдается, за исключением того, что квартиры в центре Санкт-Перербурга стоят в сренем дороже.

# %% [markdown]
# ##Шаг 5. Напишите общий вывод

# %% [markdown]
#  - Общая площадь квартир в базе данных лежит в диапазоне от 12 до 900 м2. Нормальные значения лежат в пределах от 12 до 115м2 - все что не укладывается в данный диапазон является выбросами. На гистограмме видно, что объекты больше 150 м2 крайне редки и большинство объектов имеют площадь около 50 м2. Медианное значение 52м2, среднее значение 60м2.
#  - Цена в датасете варьируется в пределах от 12190 руб до 763 млн. рублей. Нормальными значениями являются значения в диапазоне от 0.12 до 11.875 млн. рублей. Медиана равна 4.64 млн. руб, среднее значение 6.54 млн. руб. На гистограмме видно, что большинство объектов имеют цену около 5 млн, и предложения по цене больше 15 млн. крайне редки.
#  - Диапазон всех возможных значений количества комнат в наборе данных лежит в пределах от 0 до 19 комнат. Нормальными значениями ялвяются, те что попадают в диапазон от 0 - 6 комнат, все что за пределами этого диапазона - выбросы. Медианное и среднее значение - 2. На гистограмме видно, что львиная доля все квартир это 1-, 2- и 3-х комнатные квартиры. Количество комнат 4 и более встречаются уже гораздо реже.
#  - Нормальная высота потолков лежит в пределах от 2,45 - 2,85 метра. Медианное значение 2.65 метра.
#  - Основная доля объектов продается от 45 дней до 231 дня. Все что меньше 45 дней можно считать быстрой продажей. Все что больше 231 и меньше 510 дней можно считать долгой продажей.
#  -  Видны явные всплески на 45, 60 и 90 дней продажи. Возможно это связано с тем, что если объявление о продаже не было активно, то оно снималось с публикации в эти дни.
#  - Можно выделить три участка на зависимости цены от площади:
#    - 0-4 млн. здесь зависимости от цены нет и можно найти предложения с средней площадью 42м2;
#    - 4 - 18 млн. здесь наблюдается положительная линейная зависимость и с ростом цены можно найти предложения со средней площадью от 42 до 125м2;
#    - более 18 млн. здесь уже линейной зависимости от площади не наблюдается.
#
#  - Можно выделить два участка на зависимости цены от количества комнат:
#    - от 0 до 7 комнат здесь есть положиетльная нелинейная(похоже на квадратичную) зависимость между количеством комнат и средней ценой;
#    - для объектов обладающих более 8 комнатами явного тренда не наблюдается. Можно найти объекты с 10-ю комнатами, которые будут по цене примерно 6-ти комнатных объектов.
#
#  - Можно выделить два участка на зависимость цены от расстояния до центра:
#    - зона с радиусом 8 км до центра города, здесь квартиры стоят значительно дороже,
#    - зона, которая удалено от центра города более чем на 8 км, здесь средняя стоимость объектов находится около 5 млн. руб. Также выделяются 42км и 54км здесь стоимость сопоставима с объектами расположенными в центре города.
#
#  - Видно, что квартиры на первом этаже являются самыми дешевыми. Самые дорогие объекты расположены на последнем этаже. Средний ценовой диапазон присущ объектам расположенным ни на первом и ни на последнем этажах.
#
#  - Диапазон средней цены в зависимости от дня недели, в котором было  размещено объявление находится в пределах 6,24 - 6,98 млн. Самые дороги квартиры размщались в субботы, самые дешевые в воскресень, хотя изменение между максимальной и минимальной ценой почти не наблюдается.
#
#  - Минимальная средняя цена 6,23 млн зафиксирована в октябре, максимальная 7,00 млн. руб в декабре.
#
#  - Виден падающий тренд средней цены с 2014 года по 2018 год. Средняя цена в 2014 года составляла около 12 млн. руб, в 2018 - 6 млн. руб.
#
#  - Самой высокой средней стоимостью квадратного метра жилья обладает посёлок Санкт-Петербург. Там приобрести один квадратный метр жилья можно  почти за 115000 руб. На десятом месте населенный пункт Выборг. Стоимость одного квадратного метра в этом населенном пункте составляет 58000 рублей.
#
#  - На графике видно, что цена резко меняется после 8го километра. Будем считать центральной частью область, которая удалена от центра не более чем на 8 км.
#
#
#  - В центре Санкт-Петербурга основная масса объектов имеют большую площадь по сравнению со всем городом. Для центра очень большой выбор объектов недвижимости в диапазоне от 50 до 75 м2, тогда как большая часть объектов для всего города имеют площадь менее 50 м2.
#
#  - В центре Санкт-Петербурга продаются более дорогие квартиры по сравнению со всем городом. В центре большинство объектов продаются по цене от 5 до 10 млн руб, тогда как для всего города большинство объектов продаются по цене от 3 до 7 млн.
#
#
#  - Выбор однокомнатных квартир в центре в два раза меньше по сравнению с 2-х и 3-х комнатными вариантами, тогда как для всего города количество однокомнатных квартир почти одинаково по сравнению с двухкомнатными.
#
#  - Распределение по высоте потолков в центре и по всему городу приблизительн одинаково.
#
#  - Зависимость средней стоимости квартир от количество комнат для центра Санкт-Петербурга и всей базы данных одинакова, за исключением того, что в центре стоимость квартир выше.
#
#  - Зависимость стоимости квартиры от этажа для центра Санкт-Петербурга и всей базы данных одинакова. Самые дешевые объекты продаются на первом этаже, самы дорогие - на последнем, средний ценовой диапазон принадлежит объектам межды первым и последним этажами.
#
#  - Зависимость стоимости от расстояния до центра города для центра Санкт-Петербурга и всей базы данных одинакова.
#
#  - Явной зависимости средней стоимости объекта недвижимости от даты размещения не наблюдается, за исключением того, что квартиры в центре Санкт-Перербурга стоят в сренем дороже.
